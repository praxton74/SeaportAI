# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msg
import seaborn as sns

# %%
df1=pd.read_csv('/content/2019-oct.csv')
df2=pd.read_csv('/content/2019-nov.csv')
df3=pd.read_csv('/content/2019-dec.csv')

# %%
df1.head(20)
# Out:
#     Unnamed: 0               event_time        event_type  product_id  \
# 0            0  2019-10-01 00:00:00 UTC              cart     5773203
# 1            1  2019-10-01 00:00:03 UTC              cart     5773353
# 2            2  2019-10-01 00:00:07 UTC              cart     5881589
# 3            3  2019-10-01 00:00:07 UTC              cart     5723490
# 4            4  2019-10-01 00:00:15 UTC              cart     5881449
# 5            5  2019-10-01 00:00:16 UTC              cart     5857269
# 6            6  2019-10-01 00:00:19 UTC              cart     5739055
# 7            7  2019-10-01 00:00:24 UTC              cart     5825598
# 8            8  2019-10-01 00:00:25 UTC              cart     5698989
# 9            9  2019-10-01 00:00:26 UTC              view     5875317
# 10          10  2019-10-01 00:00:28 UTC              view     5692917
# 11          11  2019-10-01 00:00:28 UTC  remove_from_cart     5834172
# ...

# %%
df2.head(20)
# Out:
#     Unnamed: 0               event_time        event_type  product_id  \
# 0            0  2019-11-01 00:00:02 UTC              view   5802432.0
# 1            1  2019-11-01 00:00:09 UTC              cart   5844397.0
# 2            2  2019-11-01 00:00:10 UTC              view   5837166.0
# 3            3  2019-11-01 00:00:11 UTC              cart   5876812.0
# 4            4  2019-11-01 00:00:24 UTC  remove_from_cart   5826182.0
# 5            5  2019-11-01 00:00:24 UTC  remove_from_cart   5826182.0
# 6            6  2019-11-01 00:00:25 UTC              view   5856189.0
# 7            7  2019-11-01 00:00:32 UTC              view   5837835.0
# 8            8  2019-11-01 00:00:34 UTC  remove_from_cart   5870838.0
# 9            9  2019-11-01 00:00:37 UTC              view   5870803.0
# 10          10  2019-11-01 00:00:42 UTC  remove_from_cart   5870803.0
# 11          11  2019-11-01 00:00:46 UTC              view   5841721.0
# ...

# %%
df3.head(20)
# Out:
#     Unnamed: 0               event_time        event_type  product_id  \
# 0            0  2019-12-01 00:00:00 UTC  remove_from_cart     5712790
# 1            1  2019-12-01 00:00:00 UTC              view     5764655
# 2            2  2019-12-01 00:00:02 UTC              cart        4958
# 3            3  2019-12-01 00:00:05 UTC              view     5848413
# 4            4  2019-12-01 00:00:07 UTC              view     5824148
# 5            5  2019-12-01 00:00:09 UTC              view     5773361
# 6            6  2019-12-01 00:00:18 UTC              cart     5629988
# 7            7  2019-12-01 00:00:22 UTC              view     5807805
# 8            8  2019-12-01 00:00:27 UTC              view     5588608
# 9            9  2019-12-01 00:00:34 UTC              cart        5335
# 10          10  2019-12-01 00:00:40 UTC              cart     5755170
# 11          11  2019-12-01 00:00:44 UTC  remove_from_cart     5650294
# ...

# %%
print(df1.shape[0],df2.shape[0],df3.shape[0])
# Out:
# 22283 20077 20286

# %%
frames = [df1, df2, df3]
  
DF = pd.concat(frames)

# %%
DF.head(20)
# Out:
#     Unnamed: 0               event_time        event_type  product_id  \
# 0            0  2019-10-01 00:00:00 UTC              cart   5773203.0
# 1            1  2019-10-01 00:00:03 UTC              cart   5773353.0
# 2            2  2019-10-01 00:00:07 UTC              cart   5881589.0
# 3            3  2019-10-01 00:00:07 UTC              cart   5723490.0
# 4            4  2019-10-01 00:00:15 UTC              cart   5881449.0
# 5            5  2019-10-01 00:00:16 UTC              cart   5857269.0
# 6            6  2019-10-01 00:00:19 UTC              cart   5739055.0
# 7            7  2019-10-01 00:00:24 UTC              cart   5825598.0
# 8            8  2019-10-01 00:00:25 UTC              cart   5698989.0
# 9            9  2019-10-01 00:00:26 UTC              view   5875317.0
# 10          10  2019-10-01 00:00:28 UTC              view   5692917.0
# 11          11  2019-10-01 00:00:28 UTC  remove_from_cart   5834172.0
# ...

# %%
DF.shape
# Out:
# (62646, 10)

# %%
DF.describe()
# Out:
#          Unnamed: 0    product_id   category_id         price       user_id
# count  6.264600e+04  6.264500e+04  6.264500e+04  62645.000000  6.264500e+04
# mean   1.795648e+05  5.467475e+06  1.547552e+18      8.726305  5.022504e+08
# std    8.084449e+05  1.335589e+06  1.633781e+17     20.058331  8.662134e+07
# min    0.000000e+00  3.762000e+03  1.487580e+18      0.000000  9.794320e+06
# 25%    5.220000e+03  5.724651e+06  1.487580e+18      2.000000  4.653894e+08
# 50%    1.044050e+04  5.809912e+06  1.487580e+18      3.970000  5.392521e+08
# 75%    1.566100e+04  5.854835e+06  1.487580e+18      7.140000  5.610051e+08
# max    4.102282e+06  5.917178e+06  2.235524e+18    327.780000  5.954145e+08

# %%
DF.dtypes
# Out:
# Unnamed: 0         int64
# event_time        object
# event_type        object
# product_id       float64
# category_id      float64
# category_code     object
# brand             object
# price            float64
# user_id          float64
# user_session      object
# dtype: object

# %%
DF.isnull().sum()
# Out:
# Unnamed: 0           0
# event_time           0
# event_type           1
# product_id           1
# category_id          1
# category_code    61395
# brand            25480
# price                1
# user_id              1
# user_session        25
# dtype: int64

# %%
msg.matrix(DF, figsize=(20,8))

# %%
DF.nunique()
# Out:
# Unnamed: 0       22646
# event_time       36429
# event_type           4
# product_id       15718
# category_id        497
# category_code       10
# brand              203
# price             1261
# user_id           9618
# user_session     14515
# dtype: int64

# %%
len(pd.unique(DF['brand']))
# Out:
# 204

# %%
DF['event_type'].unique()
# Out:
# array(['cart', 'view', 'remove_from_cart', 'purchase', nan], dtype=object)

# %%
DF['price'].max()
# Out:
# 327.78

# %%
DF.pivot_table(columns=['event_type'], aggfunc='size')
# Out:
# event_type
# cart                17769
# purchase             4469
# remove_from_cart    12606
# view                27801
# dtype: int64

# %%
DF.pivot_table(columns=['brand'], aggfunc='size')
# Out:
# brand
# airnails      199
# almea          21
# andrea          6
# ardell         75
# art-visage    234
#              ...
# yoko          320
# ypsed           8
# yu-r            6
# zeitun         17
# zinger        376
# Length: 203, dtype: int64

# %%
DF.pivot_table(columns=['price'], aggfunc='size')
# Out:
# price
# 0.00      160
# 0.05       11
# 0.06       15
# 0.08       37
# 0.10        9
#          ...
# 236.51      1
# 273.02     29
# 277.78      3
# 299.81     41
# 327.78      2
# Length: 1261, dtype: int64

# %%
m1=DF['price'].mean()

# %%
DF.event_type = DF.event_type.fillna('view')
DF['price'] =  DF['price'].fillna(m1)

# %%
DF.isnull().sum()
# Out:
# Unnamed: 0           0
# event_time           0
# event_type           0
# product_id           1
# category_id          1
# category_code    61395
# brand            25480
# price                0
# user_id              1
# user_session        25
# dtype: int64

# %%
del DF['Unnamed: 0']
del DF['event_time']
del DF['product_id']
del DF['category_id']
del DF['category_code']
del DF['user_id']
del DF['user_session']
df=DF

# %%
df1=df[df['event_type']=='purchase']
df1
# Out:
#       event_type     brand  price
# 202     purchase    runail   5.32
# 204     purchase    runail   2.86
# 205     purchase    runail   2.38
# 206     purchase    runail   4.44
# 207     purchase    runail   2.62
# ...          ...       ...    ...
# 19443   purchase       uno  10.32
# 19444   purchase       uno  10.95
# 20233   purchase       NaN  10.95
# 20255   purchase  ingarden   4.92
# 20256   purchase       NaN   9.52
#
# [4469 rows x 3 columns]

# %%
df2=df1[df1['price']>100]

# %%
df2
# Out:
#       event_type    brand   price
# 20304   purchase  polarus  102.38
# 21492   purchase      jas  123.81
# 8553    purchase   strong  194.44
# 9768    purchase   strong  194.44
# 14130   purchase   strong  194.44
# 5238    purchase   sanoto  125.40

# %%
df3=df[df['event_type']=='cart']
df3
# Out:
#       event_type     brand  price
# 0           cart    runail   2.62
# 1           cart    runail   2.62
# 2           cart    lovely  13.48
# 3           cart    runail   2.62
# 4           cart    lovely   0.56
# ...          ...       ...    ...
# 20215       cart       NaN   4.44
# 20223       cart   grattol   3.02
# 20227       cart      kiss   7.92
# 20254       cart     irisk   3.33
# 20275       cart  severina   3.16
#
# [17769 rows x 3 columns]

# %%
df4=df3[df3['price']>100]
df4
# Out:
#       event_type     brand   price
# 743         cart       NaN  110.32
# 4807        cart  marathon  137.78
# 5772        cart  marathon  137.78
# 5873        cart  marathon  137.78
# 9166        cart    strong  194.44
# 15350       cart    strong  194.44
# 19453       cart       NaN  111.67
# 20706       cart  airnails  107.94
# 20712       cart       jas  123.81
# 1800        cart    strong  194.44
# 1802        cart    strong  194.44
# 3304        cart    strong  194.44
# 4262        cart    strong  273.02
# 5781        cart    strong  194.44
# 5897        cart  kosmekka  103.97
# 7621        cart    strong  194.44
# 7630        cart    strong  194.44
# 12569       cart  marathon  137.78
# 14183       cart    strong  153.17
# 18058       cart       NaN  299.81
# 18965       cart    strong  273.02
# 698         cart    strong  194.44
# 816         cart   polarus  102.38
# 3379        cart  marathon  137.78
# 4507        cart    s.care  103.17
# 4510        cart    s.care  103.17
# ...

# %%
df5=df[df['price']<100]

# %%
df5
# Out:
#       event_type   brand  price
# 0           cart  runail   2.62
# 1           cart  runail   2.62
# 2           cart  lovely  13.48
# 3           cart  runail   2.62
# 4           cart  lovely   0.56
# ...          ...     ...    ...
# 20280       view  runail   2.62
# 20281       view  masura   2.84
# 20283       view     NaN   7.14
# 20284       view     NaN  11.90
# 20285       view     NaN   4.44
#
# [62047 rows x 3 columns]

# %%
df6=df5[df5['event_type']=='view']

# %%
col_list = df6.brand.values.tolist()

# %%
import collections
frequency = collections.Counter(col_list)
print(dict(frequency))
# Out:
# {nan: 11285, 'lianail': 228, 'runail': 1994, 'f.o.x': 156, 'cnd': 351, 'ingarden': 517, 'bluesky': 266, 'pole': 149, 'lovely': 122, 'keen': 16, 'irisk': 1158, 'estel': 521, 'concept': 412, 'haruyama': 182, 'thuya': 30, 'roubloff': 110, 'masura': 1031, 'beautix': 103, 'uno': 500, 'yoko': 137, 'entity': 51, 'italwax': 303, 'max': 112, 'smart': 42, 'beauty-free': 16, 'kinetics': 98, 'shik': 75, 'de.lux': 107, 'metzger': 75, 'matrix': 36, 'depilflax': 41, 'jessnail': 354, 'levrana': 65, 'kapous': 498, 'browxenna': 92, 'kiss': 33, 'limoni': 27, 'bpw.style': 679, 'kaypro': 53, 'kaaral': 93, 'nagaraku': 119, 'staleks': 154, 'grattol': 924, 'milv': 180, 'domix': 208, 'skinlite': 22, 'enas': 8, 'profhenna': 9, 'ardell': 55, 'dizao': 26, 'oniq': 156, 'siberina': 11, 'art-visage': 124, 'severina': 106, 'shary': 15, 'markell': 68, 'cosmoprofi': 183, 'likato': 28, 'pnb': 139, 'bioaqua': 57, 'freedecor': 361, 'soleo': 6, 'polarus': 90, 'konad': 27, 'nitrile': 6, 'lador': 118, 'kosmekka': 61, 'zing
# ...

# %%
x = sorted(((v,k) for k,v in frequency.items()))
print(x[-2][1])
print(x[-3][1])
print(x[-4][1])
print(x[-5][1])
print(x[-6][1])
# Out:
# runail
# irisk
# masura
# grattol
# bpw.style
